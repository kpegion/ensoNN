# %% [markdown]
# ### Overview
#
# This notebook creates a NN following Toms et al.
#
# It expands on Toms et al. to predict El Nino or La Nina based on Nino3.4 at a specified lead time using SST anomalies as predictors
#
# It applies LRP to determine the input that contributed to the prediction.

# %% [markdown]
# ### Imports

# %%
import xarray as xr
import numpy as np
from scipy import signal

import matplotlib.pyplot as plt
import matplotlib.colors as colors

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Functions

# %%
def detrend(da):
    da.values[np.isnan(da.values)] = 0.0
    return signal.detrend(da,axis=0)

# %% [markdown]
# ### Read Data, Select times, Reverse lats

# %%
fname = '/scratch/kpegion/sst.mon.mean.COBE.nc'
ds = xr.open_dataset(fname,decode_times=True).sel(time=slice('1880-01','2017-12'))
ds=ds.reindex(lat=list(reversed(ds['lat'])))
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1656)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * time     (time) datetime64[ns] 1880-01-01 1880-02-01 ... 2017-12-01
# Data variables:
#     sst      (time, lat, lon) float32 ...
# Attributes:
#     title:            created 12/2013 from data provided by JRA
#     history:          Created 12/2012 from data obtained from JRA by ESRL/PSD
#     platform:         Analyses
#     citation:         Hirahara, S., Ishii, M., and Y. Fukuda,2014: Centennial...
#     institution:      NOAA ESRL/PSD
#     Conventions:      CF-1.2
#     dataset_title:    COBE-SST2 Sea Surface Temperature and Ice
#     original_source:  https://climate.mri-jma.go.jp/pub/ocean/cobe-sst2/
#     References:       http://www.psl.noaa.gov/data/gridded/cobe2.html

# %% [markdown]
# ### Make anomalies

# %%
ds_climo = ds.sel(time=slice('1980-01','2009-12')).groupby('time.month').mean(dim='time')
ds_anom = ds.groupby('time.month') - ds_climo

# %% [markdown]
# ### Detrend and put back into `xr.Dataset`

# %%
anoms_detrend = detrend(ds_anom['sst'])

ds_tmp=xr.DataArray(anoms_detrend,
                    coords={'time':ds['time'],
                            'lat':ds['lat'],
                            'lon': ds['lon']},
                    dims=['time','lat','lon'])        
ds_anom_detrend=ds_tmp.to_dataset(name='sst')
ds_anom_detrend
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1656)
# Coordinates:
#   * time     (time) datetime64[ns] 1880-01-01 1880-02-01 ... 2017-12-01
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
# Data variables:
#     sst      (time, lat, lon) float32 0.0 0.0 0.0 ... 0.02829 0.02819 0.02862

# %% [markdown]
# ### Make Nino3.4

# %%
ds_nino = ds_anom_detrend.sel(lat=slice(-5,5),lon=slice(360-170,360-120)).mean(dim=['lat','lon'])
ds_nino
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1656)
# Coordinates:
#   * time     (time) datetime64[ns] 1880-01-01 1880-02-01 ... 2017-12-01
# Data variables:
#     sst      (time) float32 -1.808 -0.3871 -0.3249 ... -0.4857 -0.711 -1.056

# %% [markdown]
# ### Split Train and Test

# %%
# Get the years for the Predictors (aka Features)
sst_anom_train=ds_anom_detrend.sel(time=slice('1880-01','1990-12'))
sst_anom_test=ds_anom_detrend.sel(time=slice('1990-01','2017-12'))

# Extract only El Nino and La Nina Events
sst_anom_train=sst_anom_train['sst'][0:len(sst_anom_train['time']),:,:].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')
sst_anom_test=sst_anom_test['sst'][0:len(sst_anom_train['time']),:,:].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')


# Get the years for the Predictand
nino_train=ds_nino.sel(time=slice('1880-01','1990-12'))
nino_test=ds_nino.sel(time=slice('1990-01','2017-12'))

# Select only El Nino and La nina Events
nino_train=nino_train['sst'].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')
nino_test=nino_test['sst'].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')

# %% [markdown]
# ### Get dimensions for use later

# %%
nx=len(ds['lon'])
ny=len(ds['lat'])
nt=len(ds['time'])
print(nx,ny,nt)
# Out:
# 360 180 1656

# %% [markdown]
# ### Turn into categorization problem with 1's and 0's for warm and cold events

# %%
# Predictors ( aka Features ): Training on first nt_train months 
X_train=sst_anom_train.values

# Create output vector based as a Categorical Predictand El Nino = [True,False] and La Nina = [False,True]
l_warm_train = ( nino_train > 0.5 )
l_cold_train = ( nino_train < -0.5 )
y_train = np.array([l_warm_train,l_cold_train]).T

# Get dimensions of training data
nt_train,junk=y_train.shape
y_train.shape
# Out:
# (668, 2)

# %% [markdown]
# ### Set Y for prediction problem

# %%
#nmon=1
nmon=12
y_train=y_train[nmon:nt_train,:]
X_train=X_train[0:nt_train-nmon,:,:]
nt_train=nt_train-nmon

# %%
print(X_train.shape,y_train.shape, nt_train)
# Out:
# (656, 180, 360) (656, 2) 656

# %%
print("El Nino TRAIN: ",l_warm_train[l_warm_train==True].count().values)
print("La Nina TRAIN: ",l_cold_train[l_cold_train==True].count().values)
# Out:
# El Nino TRAIN:  318
# La Nina TRAIN:  350

# %% [markdown]
# ### Make a keras model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import regularizers
from keras import initializers
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

model.add(Dense(8, input_dim=nx*ny,activation='relu',
                kernel_initializer='he_normal',
                kernel_regularizer=regularizers.l2(25),
                bias_initializer='he_normal'))

model.add(Dense(8, activation='relu',
                kernel_initializer='he_normal',
                bias_initializer='he_normal',
                kernel_regularizer=regularizers.l2(0.01)))

model.add(Dense(2, activation='softmax'))

model.compile(loss='binary_crossentropy', 
              metrics=['accuracy'],
              optimizer=optimizers.SGD(lr=0.001,nesterov=True,momentum=0.9))
# Out:
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /homes/kpegion/.conda/envs/ensonn/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ### Train the NN

# %%
XX = X_train.reshape(nt_train,nx*ny)
model.fit(XX, y_train, epochs=100, batch_size=60)
# Out:
# Epoch 1/100
# 656/656 [==============================] - 0s 675us/step - loss: 121.1123 - acc: 0.6021
# Epoch 2/100
# 656/656 [==============================] - 0s 237us/step - loss: 26.6378 - acc: 0.6372
# Epoch 3/100
# 656/656 [==============================] - 0s 231us/step - loss: 3.8925 - acc: 0.6052
# Epoch 4/100
# 656/656 [==============================] - 0s 221us/step - loss: 1.1602 - acc: 0.6540
# Epoch 5/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.9460 - acc: 0.5976
# Epoch 6/100
# 656/656 [==============================] - 0s 224us/step - loss: 0.8518 - acc: 0.6204
# Epoch 7/100
# 656/656 [==============================] - 0s 226us/step - loss: 0.8355 - acc: 0.6128
# Epoch 8/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8193 - acc: 0.6372
# Epoch 9/100
# 656/656 [==============================] - 0s 240us/step - loss: 0.8309 - acc: 0.6052
# Epoch 10/100
# 656/656 [==============================] - 0s 224us/step - loss: 0.8264 - acc: 0.6311
# Epoch 11/100
# 656/656 [==============================] - 0s 226us/step - loss: 0.8279 - acc: 0.6433
# Epoch 12/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8189 - acc: 0.6128
# Epoch 13/100
# 656/656 [==============================] - 0s 219us/step - loss: 0.8157 - acc: 0.6494
# Epoch 14/100
# 656/656 [==============================] - 0s 216us/step - loss: 0.8241 - acc: 0.6341
# Epoch 15/100
# 656/656 [==============================] - 0s 223us/step - loss: 0.8173 - acc: 0.6418
# Epoch 16/100
# 656/656 [==============================] - 0s 228us/step - loss: 0.8191 - acc: 0.6311
# Epoch 17/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8158 - acc: 0.6280
# Epoch 18/100
# 656/656 [==============================] - 0s 225us/step - loss: 0.8271 - acc: 0.6220
# Epoch 19/100
# 656/656 [==============================] - 0s 221us/step - loss: 0.8126 - acc: 0.6585
# Epoch 20/100
# 656/656 [==============================] - 0s 221us/step - loss: 0.8198 - acc: 0.6387
# Epoch 21/100
# 656/656 [==============================] - 0s 223us/step - loss: 0.8177 - acc: 0.6479
# Epoch 22/100
# 656/656 [==============================] - 0s 221us/step - loss: 0.8080 - acc: 0.6677
# Epoch 23/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8180 - acc: 0.6479
# Epoch 24/100
# 656/656 [==============================] - 0s 236us/step - loss: 0.8184 - acc: 0.6265
# Epoch 25/100
# 656/656 [==============================] - 0s 234us/step - loss: 0.8188 - acc: 0.6463
# Epoch 26/100
# 656/656 [==============================] - 0s 218us/step - loss: 0.8052 - acc: 0.6585
# Epoch 27/100
# 656/656 [==============================] - 0s 218us/step - loss: 0.8129 - acc: 0.6479
# Epoch 28/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8053 - acc: 0.6692
# Epoch 29/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8163 - acc: 0.6402
# Epoch 30/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8203 - acc: 0.6098
# Epoch 31/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8185 - acc: 0.6174
# Epoch 32/100
# 656/656 [==============================] - 0s 225us/step - loss: 0.8145 - acc: 0.6448
# Epoch 33/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8176 - acc: 0.6357
# Epoch 34/100
# 656/656 [==============================] - 0s 228us/step - loss: 0.8118 - acc: 0.6296
# Epoch 35/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8207 - acc: 0.6296
# Epoch 36/100
# 656/656 [==============================] - 0s 223us/step - loss: 0.8083 - acc: 0.6463
# Epoch 37/100
# 656/656 [==============================] - 0s 218us/step - loss: 0.8377 - acc: 0.6159
# Epoch 38/100
# 656/656 [==============================] - 0s 219us/step - loss: 0.8170 - acc: 0.6128
# Epoch 39/100
# 656/656 [==============================] - 0s 227us/step - loss: 0.8025 - acc: 0.6509
# Epoch 40/100
# 656/656 [==============================] - 0s 236us/step - loss: 0.8056 - acc: 0.6677
# Epoch 41/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8057 - acc: 0.6418
# Epoch 42/100
# 656/656 [==============================] - 0s 218us/step - loss: 0.8443 - acc: 0.6037
# Epoch 43/100
# 656/656 [==============================] - 0s 225us/step - loss: 0.8175 - acc: 0.6372
# Epoch 44/100
# 656/656 [==============================] - 0s 227us/step - loss: 0.8234 - acc: 0.6463
# Epoch 45/100
# 656/656 [==============================] - 0s 338us/step - loss: 0.8108 - acc: 0.6372
# Epoch 46/100
# 656/656 [==============================] - 0s 236us/step - loss: 0.8069 - acc: 0.6082
# Epoch 47/100
# 656/656 [==============================] - 0s 378us/step - loss: 0.8200 - acc: 0.6311
# Epoch 48/100
# 656/656 [==============================] - 0s 364us/step - loss: 0.8122 - acc: 0.6250
# Epoch 49/100
# 656/656 [==============================] - 0s 383us/step - loss: 0.8385 - acc: 0.5930
# Epoch 50/100
# 656/656 [==============================] - 0s 262us/step - loss: 0.8049 - acc: 0.6479
# Epoch 51/100
# 656/656 [==============================] - 0s 225us/step - loss: 0.8085 - acc: 0.6372
# Epoch 52/100
# 656/656 [==============================] - 0s 240us/step - loss: 0.8196 - acc: 0.6433
# Epoch 53/100
# 656/656 [==============================] - 0s 225us/step - loss: 0.8164 - acc: 0.5915
# Epoch 54/100
# 656/656 [==============================] - 0s 227us/step - loss: 0.7946 - acc: 0.6418
# Epoch 55/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8109 - acc: 0.6418
# Epoch 56/100
# 656/656 [==============================] - 0s 215us/step - loss: 0.8240 - acc: 0.6341
# Epoch 57/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8115 - acc: 0.6143
# Epoch 58/100
# 656/656 [==============================] - 0s 222us/step - loss: 0.8028 - acc: 0.6524
# Epoch 59/100
# 656/656 [==============================] - 0s 221us/step - loss: 0.8062 - acc: 0.6341
# Epoch 60/100
# 656/656 [==============================] - 0s 220us/step - loss: 0.8049 - acc: 0.6463
# Epoch 61/100
# 656/656 [==============================] - 0s 228us/step - loss: 0.7916 - acc: 0.6585
# Epoch 62/100
# 656/656 [==============================] - 0s 224us/step - loss: 0.8043 - acc: 0.6357
# Epoch 63/100
# 656/656 [==============================] - 0s 230us/step - loss: 0.7921 - acc: 0.6296
# Epoch 64/100
# 656/656 [==============================] - 0s 235us/step - loss: 0.7992 - acc: 0.6479
# Epoch 65/100
# 656/656 [==============================] - 0s 237us/step - loss: 0.7875 - acc: 0.6372
# Epoch 66/100
# 656/656 [==============================] - 0s 269us/step - loss: 0.8219 - acc: 0.5915
# Epoch 67/100
# 656/656 [==============================] - 0s 258us/step - loss: 0.7891 - acc: 0.6402
# Epoch 68/100
# 656/656 [==============================] - 0s 262us/step - loss: 0.8060 - acc: 0.6372
# Epoch 69/100
# 656/656 [==============================] - 0s 262us/step - loss: 0.7989 - acc: 0.6341
# Epoch 70/100
# 656/656 [==============================] - 0s 262us/step - loss: 0.8097 - acc: 0.6311
# Epoch 71/100
# 656/656 [==============================] - 0s 269us/step - loss: 0.8065 - acc: 0.6280
# Epoch 72/100
# 656/656 [==============================] - 0s 256us/step - loss: 0.8204 - acc: 0.6052
# Epoch 73/100
# 656/656 [==============================] - 0s 264us/step - loss: 0.8156 - acc: 0.6159
# Epoch 74/100
# 656/656 [==============================] - 0s 273us/step - loss: 0.8049 - acc: 0.6463
# Epoch 75/100
# 656/656 [==============================] - 0s 350us/step - loss: 0.7996 - acc: 0.6143
# Epoch 76/100
# 656/656 [==============================] - 0s 315us/step - loss: 0.7930 - acc: 0.6494
# Epoch 77/100
# 656/656 [==============================] - 0s 273us/step - loss: 0.8125 - acc: 0.5884
# Epoch 78/100
# 656/656 [==============================] - 0s 314us/step - loss: 0.7918 - acc: 0.6555
# Epoch 79/100
# 656/656 [==============================] - 0s 421us/step - loss: 0.7988 - acc: 0.6372
# Epoch 80/100
# 656/656 [==============================] - 0s 452us/step - loss: 0.7887 - acc: 0.6479
# Epoch 81/100
# 656/656 [==============================] - 0s 361us/step - loss: 0.7828 - acc: 0.6524
# Epoch 82/100
# 656/656 [==============================] - 0s 274us/step - loss: 0.7857 - acc: 0.6311
# Epoch 83/100
# 656/656 [==============================] - 0s 242us/step - loss: 0.7989 - acc: 0.6341
# Epoch 84/100
# 656/656 [==============================] - 0s 229us/step - loss: 0.7904 - acc: 0.6326
# Epoch 85/100
# 656/656 [==============================] - 0s 249us/step - loss: 0.7934 - acc: 0.6326
# Epoch 86/100
# 656/656 [==============================] - 0s 275us/step - loss: 0.7895 - acc: 0.6372
# Epoch 87/100
# 656/656 [==============================] - 0s 283us/step - loss: 0.8065 - acc: 0.5945
# Epoch 88/100
# 656/656 [==============================] - 0s 307us/step - loss: 0.7880 - acc: 0.6601
# Epoch 89/100
# 656/656 [==============================] - 0s 297us/step - loss: 0.8047 - acc: 0.6326
# Epoch 90/100
# 656/656 [==============================] - 0s 337us/step - loss: 0.7807 - acc: 0.6570
# Epoch 91/100
# 656/656 [==============================] - 0s 248us/step - loss: 0.7891 - acc: 0.6555
# Epoch 92/100
# 656/656 [==============================] - 0s 242us/step - loss: 0.7920 - acc: 0.6570
# Epoch 93/100
# 656/656 [==============================] - 0s 362us/step - loss: 0.7906 - acc: 0.6372
# Epoch 94/100
# 656/656 [==============================] - 0s 454us/step - loss: 0.7964 - acc: 0.6357
# Epoch 95/100
# 656/656 [==============================] - 0s 303us/step - loss: 0.7848 - acc: 0.6418
# Epoch 96/100
# 656/656 [==============================] - 0s 290us/step - loss: 0.7952 - acc: 0.6372
# Epoch 97/100
# 656/656 [==============================] - 0s 270us/step - loss: 0.7844 - acc: 0.6479
# Epoch 98/100
# 656/656 [==============================] - 0s 280us/step - loss: 0.7867 - acc: 0.6585
# Epoch 99/100
# 656/656 [==============================] - 0s 294us/step - loss: 0.8150 - acc: 0.6052
# Epoch 100/100
# 656/656 [==============================] - 0s 380us/step - loss: 0.8070 - acc: 0.6372

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 518408
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 518,498
# Trainable params: 518,498
# Non-trainable params: 0
# _________________________________________________________________

# %%
# evaluate the keras model
_, accuracy = model.evaluate(XX, y_train)
print('Training Accuracy: %.2f' % (accuracy*100))
# Out:
# 656/656 [==============================] - 0s 342us/step
# Training Accuracy: 60.21

# %% [markdown]
# ### Test the Model Accuracy using Test Data
# Need to setup for N-month lead

# %%
# Predictors ( aka Features )
X_test=sst_anom_test.values

# Select El Nino and La Nina (Categorical Predictand)
l_warm_test = ( nino_test > 0.5 )
l_cold_test = ( nino_test < -0.5 )
y_test = np.array([l_warm_test,l_cold_test]).T

nt_test,junk=y_test.shape

y_test.shape
# Out:
# (177, 2)

# %%
#nmon=1
nmon=12
y_test=y_test[nmon:nt_test,:]
X_test=X_test[0:nt_test-nmon,:,:]
nt_test=nt_test-nmon

# %%
XX=X_test.reshape(nt_test,nx*ny)

# %%
_, test_accuracy = model.evaluate(XX, y_test)
print('Testing Accuracy: %.2f' % (test_accuracy*100))
# Out:
# 165/165 [==============================] - 0s 269us/step
# Testing Accuracy: 42.42

# %% [markdown]
# ### Apply `iNNvestigate` using all El Nino and La Nina Cases as Input

# %%
import innvestigate
import innvestigate.utils

# %%
# Predictors ( aka Features ): Training on first nt_train months 
X=ds_anom_detrend['sst'][0:nt,:,:].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all').values
nt_new,ny,nx=X.shape
X=X.reshape(nt_new,nx*ny)
print(nt_new)

# Select El Nino and La Nina (Categorical Predictand)
y=ds_nino['sst'].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')
l_warm = ( y > 0.5 )
l_cold = ( y < -0.5 )
y = np.array([l_warm,l_cold]).T

y.shape
# Out:
# 845
# (845, 2)

# %%
print("El Nino ALL: ",l_warm[l_warm==True].count().values)
print("La Nina ALL: ",l_cold[l_cold==True].count().values)
# Out:
# El Nino ALL:  410
# La Nina ALL:  435

# %%
# Strip softmax layer
model = innvestigate.utils.model_wo_softmax(model)

# Create analyzer
analyzer = innvestigate.create_analyzer("deep_taylor", model)

# Apply analyzer w.r.t. maximum activated output-neuron
a = analyzer.analyze(X)

# %%
a.shape
# Out:
# (845, 64800)

# %% [markdown]
# ### Get El Nino Cases, Reshape to `time,lat,lon`

# %%
# Get El Nino Cases
a_warm=a[l_warm==True,:]

# Reshape to time,lat,lon
tmp=a_warm.shape
a=a_warm.reshape((tmp[0],ny,nx))

# Find times corresponding to El Nino
ds_time=ds_anom_detrend['sst'][0:nt,:,:].where(np.abs(ds_nino['sst'])>0.5).dropna(dim='time',how='all')['time'][l_warm==True]

# %% [markdown]
# ### Make `xarray.Dataset`

# %%
ds_tmp=xr.DataArray(a,
                    coords={'time':ds_time,
                            'lat':ds['lat'].values,
                            'lon': ds['lon'].values},
                    dims=['time','lat','lon'])        
ds_lrp=ds_tmp.to_dataset(name='warm')

# %% [markdown]
# ### Normalize by max value in grid for each input

# %%
ds_lrp=ds_lrp/ds_lrp.max(dim=['lat','lon'])
ds_lrp
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 410)
# Coordinates:
#   * time     (time) datetime64[ns] 1880-12-01 1881-01-01 ... 2016-05-01
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
# Data variables:
#     warm     (time, lat, lon) float32 0.0 0.0 0.0 ... 3.461e-05 2.831e-05

# %% [markdown]
# ### Plot Composite Relevance for N-month prediction

# %%
from cartopy.util import add_cyclic_point
clevs=np.arange(0.0,0.8,.05)

fig = plt.figure(figsize=(11,8.5))
ax=plt.axes(projection=ccrs.Robinson(central_longitude=230))
data, lons = add_cyclic_point(ds_lrp['warm'].mean(dim='time'), coord=ds['lon'])
cs=ax.contourf(lons, ds['lat'], data,clevs,
               transform = ccrs.PlateCarree(),cmap='Blues_r',
               extend='max')
ax.add_feature(cfeature.NaturalEarthFeature('physical','land','50m', 
                                            edgecolor='gray', facecolor='gray'))
ax.coastlines()
ax.set_title('Composite of All El Nino Inputs: '+str(nmon)+'-month lead')
plt.colorbar(cs,orientation='horizontal',label='Normalized Relevance (unitless)')
plt.savefig('../figs/lrp_comp_elnino_COBE_lead'+str(nmon)+'months.png')
